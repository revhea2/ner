# %%
import nltk
import pandas as pd
from nltk import pos_tag
from nltk import ne_chunk
from nltk.tokenize import word_tokenize

# %%
text = """
    In 1995 he joined the Computer Science Department at Carnegie Mellon University (CMU) as a research computer scientist. In 1998 he became an assistant professor and co-director of the Robot Learning Laboratory at CMU. As a faculty member at CMU, he co-founded the Master's Program in Automated Learning and Discovery, which later would become a Ph.D. program in the broad area of machine learning and scientific discovery. In 2001 Thrun spent a sabbatical year at Stanford University. He returned to CMU to an endowed professorship, the Finmeccanica Associate Professor of Computer Science and Robotics.
"""
words = word_tokenize(text)
pt_words = pos_tag(words)

# %%
chunks = ne_chunk(pt_words, binary=True)


for chunk in chunks:
    print(chunk)
# Out:
# ('In', 'IN')
# ('1995', 'CD')
# ('he', 'PRP')
# ('joined', 'VBD')
# ('the', 'DT')
# (NE Computer/NNP Science/NNP Department/NNP)
# ('at', 'IN')
# (NE Carnegie/NNP Mellon/NNP University/NNP)
# ('(', '(')
# (NE CMU/NNP)
# (')', ')')
# ('as', 'IN')
# ('a', 'DT')
# ('research', 'NN')
# ('computer', 'NN')
# ('scientist', 'NN')
# ('.', '.')
# ('In', 'IN')
# ('1998', 'CD')
# ('he', 'PRP')
# ('became', 'VBD')
# ('an', 'DT')
# ('assistant', 'NN')
# ('professor', 'NN')
# ('and', 'CC')
# ('co-director', 'NN')
# ('of', 'IN')
# ('the', 'DT')
# (NE Robot/NNP Learning/NNP Laboratory/NNP)
# ('at', 'IN')
# (NE CMU/NNP)
# ('.', '.')
# ('As', 'IN')
# ('a', 'DT')
# ('faculty', 'NN')
# ('member', 'NN')
# ('at', 'IN')
# (NE CMU/NNP)
# (',', ',')
# ('he', 'PRP')
# ('co-founded', 'VBD')
# ('the', 'DT')
# (NE Master/NNP)
# ("'s", 'POS')
# ('Program', 'NNP')
# ('in', 'IN')
# (NE Automated/NNP Learning/NNP)
# ('and', 'CC')
# (NE Discovery/NNP)
# (',', ',')
# ('which', 'WDT')
# ('later', 'RB')
# ('would', 'MD')
# ('become', 'VB')
# ('a', 'DT')
# ('Ph.D.', 'NNP')
# ('program', 'NN')
# ('in', 'IN')
# ('the', 'DT')
# ('broad', 'JJ')
# ('area', 'NN')
# ('of', 'IN')
# ('machine', 'NN')
# ('learning', 'NN')
# ('and', 'CC')
# ('scientific', 'JJ')
# ('discovery', 'NN')
# ('.', '.')
# ('In', 'IN')
# ('2001', 'CD')
# ('Thrun', 'NNP')
# ('spent', 'VBD')
# ('a', 'DT')
# ('sabbatical', 'JJ')
# ('year', 'NN')
# ('at', 'IN')
# (NE Stanford/NNP University/NNP)
# ('.', '.')
# ('He', 'PRP')
# ('returned', 'VBD')
# ('to', 'TO')
# (NE CMU/NNP)
# ('to', 'TO')
# ('an', 'DT')
# ('endowed', 'VBN')
# ('professorship', 'NN')
# (',', ',')
# ('the', 'DT')
# (NE Finmeccanica/NNP Associate/NNP Professor/NNP)
# ('of', 'IN')
# (NE Computer/NNP Science/NNP)
# ('and', 'CC')
# ('Robotics', 'NNPS')
# ('.', '.')

# %%
entities = []
labels = []

for chunk in chunks:
    if hasattr(chunk, 'label'):
        entities.append(' '.join(c[0] for c in chunk))
        labels.append(chunk.label())
entities_labels = list(set(zip(entities, labels)))
entities_df = pd.DataFrame(entities_labels)
entities_df.columns = ["Entities", "Labels"]
entities_df
# Out:
#                            Entities Labels
# 0                         Discovery     NE
# 1                               CMU     NE
# 2        Carnegie Mellon University     NE
# 3                  Computer Science     NE
# 4         Robot Learning Laboratory     NE
# 5                            Master     NE
# 6  Finmeccanica Associate Professor     NE
# 7       Computer Science Department     NE
# 8               Stanford University     NE
# 9                Automated Learning     NE

# %%
entities = []
labels = []

sentence = nltk.sent_tokenize(text)

for sent in sentence:
    for chunk in ne_chunk(pos_tag(word_tokenize(sent)), binary=False):
        if hasattr(chunk, "label"):
            entities.append(' '.join(c[0] for c in chunk))
            labels.append(chunk.label())

entities_labels = list(set(zip(entities, labels)))
entities_df = pd.DataFrame(entities_labels)
entities_df.columns = ["Entities", "Labels"]
entities_df
# Out:
#                        Entities        Labels
# 0                         Robot  ORGANIZATION
# 1              Computer Science  ORGANIZATION
# 2                           CMU  ORGANIZATION
# 3    Carnegie Mellon University  ORGANIZATION
# 4        Finmeccanica Associate  ORGANIZATION
# 5                      Robotics        PERSON
# 6                        Master  ORGANIZATION
# 7                     Automated           GPE
# 8                     Discovery        PERSON
# 9   Computer Science Department  ORGANIZATION
# 10          Stanford University  ORGANIZATION

# %%
import spacy
from spacy import displacy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-6f70af4282c0> in <module>
# ----> 1 import spacy
#       2 from spacy import displacy
#
# ModuleNotFoundError: No module named 'spacy'

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(text)
doc.ents
entities = []
labels = []

position_start = []
position_end = []

for ent in doc.ents:
    entities.append(ent)
    labels.append(ent.label_)
    position_start.append(ent.start_char)
    position_end.append(ent.end_char)

df = pd.DataFrame({'Entities': entities, 'Labels': labels, 'Position Start': position_start, 'Position End': position_end})
df

# %%
spacy.explain('GPE')
